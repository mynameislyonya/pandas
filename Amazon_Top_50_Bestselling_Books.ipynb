# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px

# %%
df = pd.read_csv('/content/bestsellers with categories.csv')

# %%
df
# Out:
#                                                   Name  \
# 0                        10-Day Green Smoothie Cleanse
# 1                                    11/22/63: A Novel
# 2              12 Rules for Life: An Antidote to Chaos
# 3                               1984 (Signet Classics)
# 4    5,000 Awesome Facts (About Everything!) (Natio...
# ..                                                 ...
# 545       Wrecking Ball (Diary of a Wimpy Kid Book 14)
# 546  You Are a Badass: How to Stop Doubting Your Gr...
# 547  You Are a Badass: How to Stop Doubting Your Gr...
# 548  You Are a Badass: How to Stop Doubting Your Gr...
# 549  You Are a Badass: How to Stop Doubting Your Gr...
#
#                        Author  User Rating  Reviews  Price  Year        Genre
# 0                    JJ Smith          4.7    17350      8  2016  Non Fiction
# 1                Stephen King          4.6     2052     22  2011      Fiction
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 550 entries, 0 to 549
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Name         550 non-null    object
#  1   Author       550 non-null    object
#  2   User Rating  550 non-null    float64
#  3   Reviews      550 non-null    int64
#  4   Price        550 non-null    int64
#  5   Year         550 non-null    int64
#  6   Genre        550 non-null    object
# dtypes: float64(1), int64(3), object(3)
# memory usage: 30.2+ KB

# %%
df.describe()
# Out:
#        User Rating       Reviews       Price         Year
# count   550.000000    550.000000  550.000000   550.000000
# mean      4.618364  11953.281818   13.100000  2014.000000
# std       0.226980  11731.132017   10.842262     3.165156
# min       3.300000     37.000000    0.000000  2009.000000
# 25%       4.500000   4058.000000    7.000000  2011.000000
# 50%       4.700000   8580.000000   11.000000  2014.000000
# 75%       4.800000  17253.250000   16.000000  2017.000000
# max       4.900000  87841.000000  105.000000  2019.000000

# %%
df.columns = df.columns.str.lower()

# %%
df.columns = df.columns.str.replace(' ','_')

# %% [markdown]
# # **Top 10 best-selling books**

# %%
df_top_10 = df.groupby('name')\
.agg({'author':'count'})\
.reset_index()\
.rename(columns={'author':'cnt'})\
.sort_values(by='cnt', ascending=False).head(10)

# %%
df_top_10
# Out:
#                                                   name  cnt
# 191  Publication Manual of the American Psychologic...   10
# 209                                StrengthsFinder 2.0    9
# 178                          Oh, the Places You'll Go!    8
# 310                        The Very Hungry Caterpillar    7
# 219  The 7 Habits of Highly Effective People: Power...    7
# 243  The Four Agreements: A Practical Guide to Pers...    6
# 140  Jesus Calling: Enjoying Peace in His Presence ...    6
# 281                       The Official SAT Study Guide    5
# 322                              To Kill a Mockingbird    5
# 216  The 5 Love Languages: The Secret to Love That ...    5

# %% [markdown]
# # **Top 10 Authors**

# %%
df_top_10a = df.groupby('author')\
.agg({'name':'count'})\
.reset_index()\
.rename(columns={'name':'cnt'})\
.sort_values(by='cnt', ascending=False).head(10)

# %%
df_top_10a
# Out:
#                                  author  cnt
# 120                         Jeff Kinney   12
# 92                         Gary Chapman   11
# 226                     Suzanne Collins   11
# 197                        Rick Riordan   11
# 11   American Psychological Association   10
# 90                               Gallup    9
# 73                            Dr. Seuss    9
# 199                         Rob Elliott    8
# 83                           Eric Carle    7
# 27                        Bill O'Reilly    7

# %%
fig = px.bar(df_top_10a, x='author', y='cnt', title='Top 10 Authors', width=800, height=400)
fig.update_layout(xaxis_tickangle=-70)
fig.update_layout(width=800, height=600)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Rating**

# %%
fig = px.histogram(df, x="user_rating",labels={'':'The Number of Books'},title="User Rating Histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
def popularity(x):
  if x >= 4.8:
    return 'Extremely Popular'
  elif x >= 4.5:
    return 'Very Popular'
  elif x >= 4.0:
    return 'Fairly Popular'
  else:
    return 'Popular'

# %%
df['popularity'] = df['user_rating'].apply(popularity)

# %%
df.groupby('popularity').agg({'genre':'count'})
# Out:
#                    genre
# popularity
# Extremely Popular    179
# Fairly Popular        91
# Popular                7
# Very Popular         273

# %%
grouped = df.groupby('popularity').agg({'genre':'count'}).reset_index()

fig = px.bar(grouped, x='popularity', y='genre', title='Distribution of Genres by Popularity',
             labels={'popularity':'Popularity', 'genre':'Number of Genres'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Reviews**

# %%
fig = px.histogram(df, x="reviews",labels={'':'The Number of Books'},title="Reviews Histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Price**

# %%
fig = px.histogram(df, x="price",labels={'':'The Number of Books'},title="Price Histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **Book Genre**

# %%
fig = px.histogram(df, x="genre",labels={'':'The Number of Books'},title="Book Genre Histogram")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig = px.scatter_matrix(df, dimensions=["user_rating","genre"], color="user_rating",title="Scatter Plot shows the relationship between Rating and Genre")
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
